# %%
import pandas as pd
df = pd.read_csv('fire data.csv')
df1 = df.where(df['FIRE_TYPE'] == 'Primary Fire').dropna()
df2 = df.where(df['FIRE_TYPE'] == 'Non-Primary Fire').dropna()

# %%
df1.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# </style>
# <table id="T_23611" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_23611_level0_col0" class="col_heading level0 col0" >COUNTRY</th>
#       <th id="T_23611_level0_col1" class="col_heading level0 col1" >FINANCIAL_YEAR</th>
#       <th id="T_23611_level0_col2" class="col_heading level0 col2" >FIRE_TYPE</th>
#       <th id="T_23611_level0_col3" class="col_heading level0 col3" >TOTAL_FIRES</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23611_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_23611_row0_col0" class="data row0 col0" >England</td>
#       <td id="T_23611_row0_col1" class="data row0 col1" >1981/82</td>
#       <td id="T_23611_row0_col2" class="data row0 col2" >Primary Fire</td>
#       <td id="T_23611_row0_col3" class="data row0 col3" >115,176</td>
#     </tr>
#     <tr>
# ...

# %%
df2.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# </style>
# <table id="T_e9614" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e9614_level0_col0" class="col_heading level0 col0" >COUNTRY</th>
#       <th id="T_e9614_level0_col1" class="col_heading level0 col1" >FINANCIAL_YEAR</th>
#       <th id="T_e9614_level0_col2" class="col_heading level0 col2" >FIRE_TYPE</th>
#       <th id="T_e9614_level0_col3" class="col_heading level0 col3" >TOTAL_FIRES</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e9614_level0_row0" class="row_heading level0 row0" >14</th>
#       <td id="T_e9614_row0_col0" class="data row0 col0" >England</td>
#       <td id="T_e9614_row0_col1" class="data row0 col1" >1995/96</td>
#       <td id="T_e9614_row0_col2" class="data row0 col2" >Non-Primary Fire</td>
#       <td id="T_e9614_row0_col3" class="data row0 col3" >321,676</td>
#     </tr>
#     <tr>
# ...
