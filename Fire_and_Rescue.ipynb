# %%
import pandas as pd
df = pd.read_excel('FIRE0101.xlsx',sheet_name='Data - population')
columnToDelete = ['CALENDAR_YEAR']
df = df.drop(columnToDelete, axis=1)

# %%
df.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_0f7cf_row0_col2 {
#   background-color: #dd2a25;
#   color: #f1f1f1;
# }
# #T_0f7cf_row1_col2, #T_0f7cf_row2_col2, #T_0f7cf_row3_col2, #T_0f7cf_row4_col2, #T_0f7cf_row5_col2, #T_0f7cf_row6_col2, #T_0f7cf_row7_col2, #T_0f7cf_row8_col2 {
#   background-color: #dc2924;
#   color: #f1f1f1;
# }
# #T_0f7cf_row9_col2, #T_0f7cf_row10_col2, #T_0f7cf_row11_col2, #T_0f7cf_row12_col2, #T_0f7cf_row13_col2 {
#   background-color: #db2824;
#   color: #f1f1f1;
# }
# #T_0f7cf_row14_col2, #T_0f7cf_row15_col2 {
#   background-color: #da2723;
#   color: #f1f1f1;
# }
# #T_0f7cf_row16_col2, #T_0f7cf_row17_col2 {
#   background-color: #d92523;
#   color: #f1f1f1;
# }
# #T_0f7cf_row18_col2, #T_0f7cf_row19_col2 {
#   background-color: #d82422;
#   color: #f1f1f1;
# }
# #T_0f7cf_row20_col2 {
#   background-color: #d72322;
#   color: #f1f1f1;
# }
# #T_0f7cf_row21_col2, #T_0f7cf_row22_col2 {
#   background-color: #d52221;
#   color: #f1f1f1;
# }
# ...

# %%
import pandas as pd
df1 = pd.read_excel('FIRE0101.xlsx',sheet_name='Data - incidents')

# %%
df1.style.background_gradient(cmap='OrRd')
# Out:
# <style type="text/css">
# #T_f1482_row0_col2 {
#   background-color: #a30000;
#   color: #f1f1f1;
# }
# #T_f1482_row1_col2 {
#   background-color: #a90000;
#   color: #f1f1f1;
# }
# #T_f1482_row2_col2 {
#   background-color: #890000;
#   color: #f1f1f1;
# }
# #T_f1482_row3_col2 {
#   background-color: #970000;
#   color: #f1f1f1;
# }
# #T_f1482_row4_col2 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# #T_f1482_row5_col2 {
#   background-color: #bc0c08;
#   color: #f1f1f1;
# }
# #T_f1482_row6_col2 {
#   background-color: #c1120c;
#   color: #f1f1f1;
# }
# #T_f1482_row7_col2 {
#   background-color: #be0f0a;
#   color: #f1f1f1;
# }
# #T_f1482_row8_col2 {
#   background-color: #d12719;
#   color: #f1f1f1;
# }
# #T_f1482_row9_col2 {
#   background-color: #e14630;
#   color: #f1f1f1;
# }
# #T_f1482_row10_col2 {
#   background-color: #e9573d;
#   color: #f1f1f1;
# }
# #T_f1482_row11_col2 {
#   background-color: #ef6447;
#   color: #f1f1f1;
# }
# #T_f1482_row12_col2 {
# ...

# %%
import pandas as pd
df2 = pd.read_excel('FIRE0103.xlsx',sheet_name='Data - fires')

# %%
df2.style.background_gradient(cmap='OrRd')
# Out:
# <style type="text/css">
# #T_17385_row0_col3, #T_17385_row39_col3 {
#   background-color: #fddeb3;
#   color: #000000;
# }
# #T_17385_row1_col3 {
#   background-color: #fdddb1;
#   color: #000000;
# }
# #T_17385_row2_col3 {
#   background-color: #fddcaf;
#   color: #000000;
# }
# #T_17385_row3_col3, #T_17385_row4_col3 {
#   background-color: #fdd9aa;
#   color: #000000;
# }
# #T_17385_row5_col3, #T_17385_row7_col3, #T_17385_row44_col3, #T_17385_row46_col3 {
#   background-color: #fdd8a7;
#   color: #000000;
# }
# #T_17385_row6_col3 {
#   background-color: #fdd9a8;
#   color: #000000;
# }
# #T_17385_row8_col3, #T_17385_row40_col3 {
#   background-color: #fdd6a2;
#   color: #000000;
# }
# #T_17385_row9_col3, #T_17385_row33_col3, #T_17385_row76_col3 {
#   background-color: #fdd5a0;
#   color: #000000;
# }
# #T_17385_row10_col3, #T_17385_row12_col3, #T_17385_row77_col3, #T_17385_row78_col3, #T_17385_row79_col3, #T_17385_row80_col3, #T_17385_row81_col3 {
#   background-color: #fdd19b;
# ...
